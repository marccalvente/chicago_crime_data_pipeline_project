# %%
# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  username="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("ijzp-q8t2", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df
# Out:
#             id case_number                     date                  block  \
# 0     12859828    JF435379  2022-10-13T23:59:00.000    080XX S LOOMIS BLVD
# 1     12858646    JF433752  2022-10-13T23:57:00.000    035XX N LINCOLN AVE
# 2     12859575    JF433754  2022-10-13T23:53:00.000    070XX S CREGIER AVE
# 3     12858606    JF433749  2022-10-13T23:52:00.000       063XX N BELL AVE
# 4     12858557    JF433770  2022-10-13T23:47:00.000    038XX W CHICAGO AVE
# ...        ...         ...                      ...                    ...
# 1995  12855860    JF430249  2022-10-10T22:08:00.000      028XX W FULTON ST
# 1996  12855565    JF429936  2022-10-10T22:00:00.000        032XX W POLK ST
# 1997  12855657    JF430165  2022-10-10T22:00:00.000   091XX S PHILLIPS AVE
# 1998  12855680    JF430015  2022-10-10T22:00:00.000  037XX W ARTHINGTON ST
# 1999  12855921    JF430360  2022-10-10T22:00:00.000      069XX S MORGAN ST
#
#       iucr         primary_type                          description  \
# 0     2820        OTHER OFFENSE                     TELEPHONE THREAT
# 1     051B              ASSAULT           AGGRAVATED - OTHER FIREARM
# 2     0560              ASSAULT                               SIMPLE
# 3     0430              BATTERY  AGGRAVATED - OTHER DANGEROUS WEAPON
# 4     1506         PROSTITUTION                SOLICIT ON PUBLIC WAY
# ...    ...                  ...                                  ...
# 1995  1320      CRIMINAL DAMAGE                           TO VEHICLE
# 1996  0910  MOTOR VEHICLE THEFT                           AUTOMOBILE
# 1997  0910  MOTOR VEHICLE THEFT                           AUTOMOBILE
# 1998  1310      CRIMINAL DAMAGE                          TO PROPERTY
# 1999  0910  MOTOR VEHICLE THEFT                           AUTOMOBILE
#
#      location_description  arrest  domestic  ...      longitude  \
# 0         OTHER (SPECIFY)   False     False  ...  -87.658526697
# 1              RESTAURANT   False     False  ...  -87.673070358
# 2               APARTMENT   False     False  ...  -87.581256707
# 3               APARTMENT   False     False  ...  -87.686180824
# 4                SIDEWALK    True     False  ...  -87.722805855
# ...                   ...     ...       ...  ...            ...
# 1995               STREET   False     False  ...  -87.697476901
# 1996               STREET   False     False  ...  -87.706483396
# 1997               STREET   False     False  ...  -87.564590143
# 1998            APARTMENT   False      True  ...  -87.718525212
# 1999               STREET   False     False  ...  -87.649340537
#
#                                                location  \
# 0     {'latitude': '41.748152866', 'longitude': '-87...
# 1     {'latitude': '41.945991574', 'longitude': '-87...
# 2     {'latitude': '41.767228929', 'longitude': '-87...
# 3     {'latitude': '41.996622677', 'longitude': '-87...
# 4     {'latitude': '41.895397041', 'longitude': '-87...
# ...                                                 ...
# 1995  {'latitude': '41.886524661', 'longitude': '-87...
# 1996  {'latitude': '41.870953916', 'longitude': '-87...
# 1997  {'latitude': '41.729357042', 'longitude': '-87...
# 1998  {'latitude': '41.8699021', 'longitude': '-87.7...
# 1999  {'latitude': '41.768088042', 'longitude': '-87...
#
#      :@computed_region_awaf_s7ux :@computed_region_6mkv_f3dw  \
# 0                             18                       21554
# 1                             16                        4449
# 2                             32                       22538
# 3                             42                        4450
# 4                             41                        4299
# ...                          ...                         ...
# 1995                          41                       21184
# 1996                          36                       21572
# 1997                          43                       21202
# 1998                          36                       21572
# 1999                          17                       21559
#
#      :@computed_region_vrxf_vc4k :@computed_region_bdys_3d7i  \
# 0                             70                         575
# 1                             57                         239
# 2                             39                         381
# 3                             20                          53
# 4                             24                         456
# ...                          ...                         ...
# 1995                          28                          50
# 1996                          28                          36
# 1997                          44                         493
# 1998                          28                          98
# 1999                          66                         410
#
#      :@computed_region_43wa_7qmu :@computed_region_rpca_8um6  \
# 0                             13                          59
# 1                             18                          22
# 2                             33                          24
# 3                             27                          50
# 4                             45                          30
# ...                          ...                         ...
# 1995                          46                          28
# 1996                          14                          30
# 1997                          37                          25
# 1998                          14                          30
# 1999                          32                          11
#
#      :@computed_region_d9mm_jgwp :@computed_region_d3ds_rm58
# 0                             20                         230
# 1                              5                          19
# 2                             18                         212
# 3                             11                          52
# 4                             16                          66
# ...                          ...                         ...
# 1995                          15                          77
# 1996                          16                         140
# 1997                          19                         238
# 1998                          16                         141
# 1999                          17                         215
#
# [2000 rows x 30 columns]
